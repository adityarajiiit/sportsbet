# %%
def makeDefaultState(overrides=None):
    state={
        "query":"",
        "intent":"",
        "confidence":0.0,
        "slots":{},
        "context":{},
        "user-id":"",
        "user-profile":{},
        "user-recent-bets":[],
        "user-portfolio":[],
        "user-wallet":{},
        "match-data":{},
        "live-score":{},
        "rag-chunks":[],
        "output":{},
        "quality-score":0.0,
        "reflection-count":0,
        "messages":[],
    }
    if overrides:
        state.update(overrides)
    return state
