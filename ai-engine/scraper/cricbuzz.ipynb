# %%
import sys
sys.path.insert(0,'/mnt/AEA8F340A8F3059D/sportsbet/ai-engine')

# %%
import httpx
from bs4 import BeautifulSoup
import logging

# %%
logger=logging.getLogger(__name__)

# %%
async def scrape_cricbuzz_news(query:str="cricket")->list[dict]:
    articles=[]
    baseurl="https://www.cricbuzz.com"
    try:
        async with httpx.AsyncClient() as client:
            resp = await client.get(
                f"{baseurl}/cricket-news",
            )
            if resp.status_code!=200:
                return articles
            soup=BeautifulSoup(resp.text,"html.parser")
            items=soup.select("div.flex.flex-col.gap-2.py-4.px-2")
            for item in items[:10]:
                title=item.select_one("a.font-bold")
                desc=item.select_one("p.text-cbTxtSec")
                if title:
                    href=title.get("href","")
                    articles.append({
                        "title":title.get_text(strip=True),
                        "url":baseurl+href if href.startswith("/") else href,
                        "content":desc.get_text(strip=True) if desc else "",
                        "category":"cricket-news",
                    })
    except Exception as e:
        logger.warning(f"cricbuzz failed {e}")
    return articles

# %%
await scrape_cricbuzz_news()
# Out:
# [{'title': 'Archer, Tongue obliterate India for 76 in 125-run rout',
#   'url': 'https://www.cricbuzz.com/cricket-news/139474/archer-tongue-obliterate-india-for-76-in-125-run-rout',
#   'content': 'Chasing 202, India were blown away in the Powerplay as they crashed to their heaviest defeat in T20Is',
#   'category': 'cricket-news'},
#  {'title': "'Absolute giant of a character' - Andy Moles mourns Shapoor Zadran's demise",
#   'url': 'https://www.cricbuzz.com/cricket-news/139473/absolute-giant-of-a-character-andy-moles-mourns-shapoor-zadrans-demise',
#   'content': "Former cricketer Raees Ahmadzai called Shapoor 'the first pace bowling star of Afghanistan'",
#   'category': 'cricket-news'},
#  {'title': 'Will enhance security for India series if required: Sayeed Ibrahim Ahmed',
#   'url': 'https://www.cricbuzz.com/cricket-news/139472/will-enhance-security-for-india-series-if-required-sayeed-ibrahim-ahmed',
#   'content': "The BCB's security committee chairman said that there has been no communication yet with the BCCI over the proposed tour",
#   'category': 'cricket-news'},
#  {'title': 'Samson omission part of 2028 T20 World Cup roadmap',
#   'url': 'https://www.cricbuzz.com/cricket-news/139471/samson-omission-part-of-2028-t20-world-cup-roadmap',
#   'content': "The Player of the Tournament in the 2026 edition, Samson continues to be part of the selectors' long-term strategy, with the opener also featuring in India's Asian Games squad",
#   'category': 'cricket-news'},
#  {'title': 'Shapoor Zadran passes away after prolonged illness',
#   'url': 'https://www.cricbuzz.com/cricket-news/139470/shapoor-zadran-passes-away-after-prolonged-illness',
#   'content': 'The former Afghanistan fast bowler was undergoing treatment in Delhi for an immune system disorder',
#   'category': 'cricket-news'},
#  {'title': 'Nahid Rana rues bowling let-off in loss to Zimbabwe',
#   'url': 'https://www.cricbuzz.com/cricket-news/139469/nahid-rana-rues-bowling-let-off-in-loss-to-zimbabwe',
#   'content': 'Zimbabwe were once reeling at 70/8, but finished with 141 and ended up defending it',
#   'category': 'cricket-news'},
#  {'title': 'Sri Lanka push lead after Greaves, Hope tons',
#   'url': 'https://www.cricbuzz.com/cricket-news/139468/sri-lanka-push-lead-after-greaves-hope-tons',
#   'content': 'Greaves finished with 180, Hope with 112 but Sri Lanka ended Day 4 with a lead of 92 runs',
#   'category': 'cricket-news'},
#  {'title': "100 days to first ball: Inside LAKR's race to build Los Angeles' Olympic cricket home",
#   'url': 'https://www.cricbuzz.com/cricket-news/139467/100-days-to-first-ball-inside-lakrs-race-to-build-los-angeles-olympic-cricket-home',
#   'content': "A horse-racing venue, buried utilities, asbestos scares and just 100 days to pull it off. Inside the extraordinary race to build Los Angeles Knight Riders' home, set to become cricket's Olympic venue in 2028",
#   'category': 'cricket-news'},
#  {'title': "Spotlight shifts from Sooryavanshi to India's mounting concerns",
#   'url': 'https://www.cricbuzz.com/cricket-news/139466/spotlight-shifts-from-sooryavanshi-to-indias-mounting-concerns',
#   'content': 'Winless under new captain Shreyas Iyer and trailing 1-0 against England after the Ireland setback, India head to Trent Bridge desperate to arrest their slide',
#   'category': 'cricket-news'},
#  {'title': "Pacers set up Zimbabwe's stunning defence of 141",
#   'url': 'https://www.cricbuzz.com/cricket-news/139465/pacers-set-up-zimbabwes-stunning-defence-of-141',
#   'content': "Nahid Rana's 6/21, the best ODI figures by a Bangladeshi bowler, vent in vain as Zimbabwe's pace quartet blew the visitors away for a famous win",
#   'category': 'cricket-news'}]
